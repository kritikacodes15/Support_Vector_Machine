# %% [markdown]
# **Dataset Used**:
# Çinar, İ., Koklu, M., & Tasdemir, S. (2020). *Raisin [Dataset]*. UCI Machine Learning Repository. https://doi.org/10.24432/C5660T
# |

# %%
import pandas as pd

# Replace 'file.xlsx' with the path to your Excel file
df = pd.read_excel('Raisin_Dataset.xlsx')

# View the first 5 rows
df.sample(5)
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 428   48093       329.935742       187.041722      0.823784       49367
# 666  178692       594.722171       384.038046      0.763554      181288
# 795   72924       434.222666       220.491764      0.861484       77356
# 382   26908       245.755781       143.710872      0.811198       28607
# 386   65123       382.357686       218.888748      0.819925       66825
#
#        Extent  Perimeter    Class
# 428  0.745108    858.386  Kecimen
# 666  0.747046   1622.032    Besni
# 795  0.621603   1183.236    Besni
# 382  0.693487    678.815  Kecimen
# 386  0.764337   1018.353  Kecimen

# %%
df.columns
# Out:
# Index(['Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity',
#        'ConvexArea', 'Extent', 'Perimeter', 'Class'],
#       dtype='object')

# %% [markdown]
# ###Features and Target

# %%
X = df[['Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity',
       'ConvexArea', 'Extent', 'Perimeter']]
y = df['Class']

# %%
X.shape, y.shape
# Out:
# ((900, 7), (900,))

# %% [markdown]
# ### Data Preprocessing : Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
scaler.fit(X_train) 
X_train_scaled = scaler.transform(X_train) 
# .fit() means:
# ➡️ "Learn the statistics (mean and standard deviation) from X_train."
X_test_scaled = scaler.transform(X_test)
# .transform() means:
# ➡️ "Use the mean and std you learned earlier to transform the data."

# %%
X_train_scaled
# Out:
# array([[ 0.9531725 ,  0.38849113,  1.79100179, ...,  1.03729448,
#         -1.40859789,  1.36594862],
#        [ 1.39153009,  0.30663321,  2.80882493, ...,  1.31793802,
#          0.94345174,  0.90601714],
#        [ 0.07872069,  0.00387698,  0.29301415, ...,  0.03382983,
#         -0.13237134, -0.02320567],
#        ...,
#        [ 1.90157823,  1.37654143,  1.90004675, ...,  1.83167362,
#          0.08831091,  1.62914584],
#        [-0.87362688, -0.69496652, -1.13039876, ..., -0.87783644,
#         -0.82717271, -0.87115178],
#        [-0.2488586 , -0.32582005,  0.02917885, ..., -0.27006703,
#         -0.40402733, -0.28495985]], shape=(720, 7))

# %%
X_train
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 722  126149       478.877101       345.919972      0.691521      134778
# 500  143386       469.276508       397.310190      0.532160      146328
# 403   91764       433.768160       270.286095      0.782133       93480
# 163   91831       463.357872       257.951128      0.830714       95560
# 579  130868       613.172615       273.181915      0.895271      134139
# ..      ...              ...              ...           ...         ...
# 369   56477       334.588138       219.185620      0.755550       58408
# 320   61289       376.375187       208.727810      0.832135       63997
# 527  163442       594.759221       351.425687      0.806766      167471
# 125   54316       351.805261       198.417520      0.825776       55960
# 265   78883       395.100097       256.964966      0.759610       80973
#
#        Extent  Perimeter
# 722  0.624908   1549.185
# 500  0.750260   1422.014
# ...

# %% [markdown]
# X_train_scaled.head() this will not work since X_train_scaled is not a dataframe
# X_train_scaled is a NumPy array, not a Pandas DataFrame.
#
# NumPy arrays do not have a .head() method — that's specific to Pandas DataFrames.

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2,random_state = 10)

# %% [markdown]
# ### SVC(kernel = "rbf") : Not Scaled

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,y_train)
# Out:
# SVC()

# %% [markdown]
# ### Model Prediction

# %%
y_pred = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.8277777777777777

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test,y_pred)
print(report)
model. n_iter_
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.86      0.75      0.80        83
#      Kecimen       0.81      0.90      0.85        97
#
#     accuracy                           0.83       180
#    macro avg       0.83      0.82      0.82       180
# weighted avg       0.83      0.83      0.83       180
# array([229], dtype=int32)

# %% [markdown]
# ### Model Training using SVC(kernel='linear') : Not Scaled

# %%
from sklearn.svm import SVC
model1 = SVC(kernel = 'linear')
model1.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model1.predict(X_test)

# %%
model1.score(X_test,y_test)
# Out:
# 0.9055555555555556

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test,y_pred)
print(report)
model1. n_iter_
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.91      0.88      0.90        83
#      Kecimen       0.90      0.93      0.91        97
#
#     accuracy                           0.91       180
#    macro avg       0.91      0.90      0.90       180
# weighted avg       0.91      0.91      0.91       180
# array([85005907], dtype=int32)

# %% [markdown]
# #### YEAHHH ... HERE WE HAVE ACHIEVED 90 PERCENT FSCORE......
# But the number of total iterations is more here

# %% [markdown]
# ### Now we are going to train the model on scaled dataset

# %%
from sklearn.svm import SVC
model2 = SVC(kernel = 'linear')
model2.fit(X_train_scaled,y_train) # using scaled data
# Out:
# SVC(kernel='linear')

# %%
y_pred2 = model2.predict(X_test_scaled) # using scaled test data

# %% [markdown]
# 🧠 What it means:
# You trained (fit) your model with a NumPy  X_train_scaled, which has no column names.
#
# But now you're trying to make predictions using a DataFrame (like X_test), which does have column names.
#
# Scikit-learn models prefer consistency — if you trained with unnamed features (array), you should predict with unnamed features too.

# %%
model2.score(X_test_scaled,y_test)
# Out:
# 0.8833333333333333

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test,y_pred2)
print(report)
model2. n_iter_
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.90      0.84      0.87        83
#      Kecimen       0.87      0.92      0.89        97
#
#     accuracy                           0.88       180
#    macro avg       0.88      0.88      0.88       180
# weighted avg       0.88      0.88      0.88       180
# array([1214], dtype=int32)

# %% [markdown]
# ### We can clearly see here the number of iterations have reduced significantly after sacling the data and using linear kernel

# %%
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('model', SVC(kernel='linear'))
])
pipe.fit(X_train, y_train)
y_pred_using_pipe = pipe.predict(X_test)
pipe.score(X_test,y_test)
# Out:
# 0.8833333333333333

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test,y_pred_using_pipe)
print(report)
model. n_iter_
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.90      0.84      0.87        83
#      Kecimen       0.87      0.92      0.89        97
#
#     accuracy                           0.88       180
#    macro avg       0.88      0.88      0.88       180
# weighted avg       0.88      0.88      0.88       180
# array([229], dtype=int32)
